# %%
import requests
import json
import pandas as pd

recomb_df = pd.read_csv("/Users/djamillakhdar-hamina/Desktop/RECOMB_titles.csv")
recomb_title_list = recomb_df[["title"]]
sample_recomb_title_list = recomb_title_list[:5]

# %%
def crossref_retrieve_data(title_list):
    """
    :param : title_list
    :return: data_frame one column title, the other doi
    """

url_form = 'https://api.crossref.org/works?query.title='
query_paramters = '&select=title,DOI,container-title,created&mailto=george@nete.com&rows=1000'

    ## if the input is a list then join all the elements into one string using ' ' as a separator, check if empty dataframe
    if isinstance(title_list, pd.DataFrame):
        title_string = ' '.join(title_list['title'].tolist())
        title_split_list = title_string.replace(' ', '+')
    elif isinstance(title_list, pd.Series):
        title_string = ' '.join(title_list.tolist())
        title_split_list = title_string.replace(' ', '+')
    elif isinstance(title_list, list):
        title_string = ' '.join(title_list)
        title_split_list = title_string.replace(' ', '+')
    ## if the input is already a string of all the different publications simply add + in between ' '

    else:
        title_split_list = title_list.replace(' ', '+')

    ## form the request object, based on parameters found here https://github.com/CrossRef/rest-api-doc
    url = url_form + title_split_list + query_paramters
    rsp = requests.get(url)
    dict_object = json.loads(rsp.text)

    ## check if it the request went throu

    items_list = dict_object.get('message')
    items_list = items_list['items']

    ## initialize local variables to operate after loop
    doi_array = []
    title_array = []
    journal_array = []
    publication_date_array = []
    for item in items_list:
        if item['DOI']:
            value = item['DOI']
            doi_array.append(value)
        elif item['title']:
            value = item['title'][0]
            title_array.append(value)
        elif item['container-title']:
            value = item['container-title'][0]
            journal_array.append(value)
        elif item['created']:
            value = item['created'][1]
            publication_date_array.append(value)

    ## pandas dataframe equal length sequences (list, series, etc.)
    ## create dictionary of sequences , lists, input for dataframe
    data_df = {'Title': title_array,
               'DOI': doi_array,
               'Journal': journal_array,
               'Publication_Date ': publication_date_array}

    ## create a pandas dataframe taking dictionary of lists as input
    title_doi_df = pd.DataFrame(data_df)


    return title_doi_df


a= crossref_retrieve_data(sample_recomb_title_list)
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-842ef6fa6884> in <module>
#      72
#      73
# ---> 74 a= crossref_retrieve_data(sample_recomb_title_list)
#      75 a
#
# <ipython-input-10-842ef6fa6884> in crossref_retrieve_data(title_list)
#      66
#      67     ## create a pandas dataframe taking dictionary of lists as input
# ---> 68     title_doi_df = pd.DataFrame(data_df)
#      69
#      70
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
ac
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-22d3df552558> in <module>
# ----> 1 a= crossref_retrieve_data(sample_recomb_title_list)
#       2 a
#
# <ipython-input-4-7c0b23f82c9c> in crossref_retrieve_data(title_list)
#      57
#      58     ## create a pandas dataframe taking dictionary of lists as input
# ---> 59     title_doi_df = pd.DataFrame(data_df)
#      60
#      61
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
def crossref_retrieve_data(title_list):
    """
    :param : title_list
    :return: data_frame one column title, the other doi
    """

    url= 'https://api.crossref.org/works?query.title=A+new+methodology+for+constructing+a+publication-level&select=title,DOI,container-title,created&rows=200'
    ## if the input is a list then join all the elements into one string using ' ' as a separator, check if empty dataframe
    if isinstance(title_list, pd.DataFrame):
        title_string = ' '.join(title_list['title'].tolist())
        title_split_list = title_string.replace(' ', '+')
    elif isinstance(title_list, pd.Series):
        title_string = ' '.join(title_list.tolist())
        title_split_list = title_string.replace(' ', '+')
    elif isinstance(title_list, list):
        title_string = ' '.join(title_list)
        title_split_list = title_string.replace(' ', '+')
    ## if the input is already a string of all the different publications simply add + in between ' '

    else:
        title_split_list = title_list.replace(' ', '+')

    ## form the request object, based on parameters found here https://github.com/CrossRef/rest-api-doc
    rsp = requests.get(url)
    dict_object = json.loads(rsp.text)

    ## check if it the request went throu

    items_list = dict_object.get('message').get('items')
    
    ## initialize local variables to operate after loop
    doi_array = []
    title_array = []
    journal_array = []
    publication_date_array = []
    for item in items_list:
        if item['DOI']:
            value = item['DOI']
            doi_array.append(value)
        elif item['title']:
            value = item['title'][0]
            title_array.append(value)
        elif item['container-title']:
            value = item['container-title'][0]
            journal_array.append(value)
        elif item['created']:
            value = item['created'][1]
            publication_date_array.append(value)

    ## pandas dataframe equal length sequences (list, series, etc.)
    ## create dictionary of sequences , lists, input for dataframe
    data_df = {'Title': title_array,
               'DOI': doi_array,
               'Journal': journal_array,
               'Publication_Date ': publication_date_array}

    ## create a pandas dataframe taking dictionary of lists as input
    title_doi_df = pd.DataFrame(data_df)
    return title_doi_df


a= crossref_retrieve_data(sample_recomb_title_list)
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-54aa1da6b4cf> in <module>
#      63
#      64
# ---> 65 a= crossref_retrieve_data(sample_recomb_title_list)
#      66 a
#
# <ipython-input-11-54aa1da6b4cf> in crossref_retrieve_data(title_list)
#      57
#      58     ## create a pandas dataframe taking dictionary of lists as input
# ---> 59     title_doi_df = pd.DataFrame(data_df)
#      60
#      61
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length
